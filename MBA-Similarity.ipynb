# %% [markdown]
# ### Market Basket Analysis - Record Linkage
# ### Encontrando produtos semelhantes em uma lista de itens ofertados em um site.

# %% [markdown]
# #### Introdução:
# Em um dataset de cadastro de produtos ou em um dataset oriundo de uma raspagem de um site de compras, é muito comum encontrar itens muito parecidos com as mesmas características, fabricante ou modelo e pouca variação nas descrições. Quando nos deparamos com esse tipo de situação, pode ser necessário agrupá-los para fazer alguma análise ou até mesmo há situações onde precisamos apenas identificá-los. Nesse exercício, não faremos agrupamentos, vamos identificar os itens e quais deles possuem descrições semelhantes.
#
# ##### Para esse exercício, será utilizado um dataset de produtos vendidos no site da Amazon que está disponível no Kaggle no link: https://www.kaggle.com/promptcloud/amazon-product-dataset-2020

# %% [markdown]
# ##### 1º - Descompactar o arquivo

# %%
import zipfile

with zipfile.ZipFile("marketing_sample_for_amazon_com-ecommerce__20200101_20200131__10k_data.csv.zip","r") as zip_ref:
    zip_ref.extractall("mba-dataset")

# %% [markdown]
# ##### 2º - Carregar os dados em um DataFrame com o pandas

# %%
import pandas as pd

# %%
# configuração para apresentar todo o conteúdo da célula
pd.set_option('display.max_colwidth', None)

# gravar os dados do arquivo no DataFrame
df = pd.read_csv('mba-dataset\marketing_sample_for_amazon_com-ecommerce__20200101_20200131__10k_data.csv')

# %%
# quantidade de linhas e colunas do DataFrame
df.shape
# Out:
# (10002, 28)

# %%
# vamos olhar as colunas que esse dataset apresenta
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10002 entries, 0 to 10001
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Uniq Id                10002 non-null  object
#  1   Product Name           10002 non-null  object
#  2   Brand Name             0 non-null      float64
#  3   Asin                   0 non-null      float64
#  4   Category               9172 non-null   object
#  5   Upc Ean Code           34 non-null     object
#  6   List Price             0 non-null      float64
#  7   Selling Price          9895 non-null   object
#  8   Quantity               0 non-null      float64
#  9   Model Number           8232 non-null   object
#  10  About Product          9729 non-null   object
#  11  Product Specification  8370 non-null   object
#  12  Technical Details      9212 non-null   object
#  13  Shipping Weight        8864 non-null   object
#  14  Product Dimensions     479 non-null    object
#  15  Image                  10002 non-null  object
#  16  Variants               2478 non-null   object
#  17  Sku                    0 non-null      float64
#  18  Product Url            10002 non-null  object
#  19  Stock                  0 non-null      float64
#  20  Product Details        0 non-null      float64
#  21  Dimensions             0 non-null      float64
#  22  Color                  0 non-null      float64
#  23  Ingredients            0 non-null      float64
#  24  Direction To Use       0 non-null      float64
#  25  Is Amazon Seller       10002 non-null  object
#  26  Size Quantity Variant  0 non-null      float64
#  27  Product Description    0 non-null      float64
# dtypes: float64(13), object(15)
# memory usage: 2.1+ MB

# %%
# agora veremos as primeiras e últimas linhas
df
# Out:
#                                 Uniq Id  \
# 0      4c69b61db1fc16e7013b43fc926e502d
# 1      66d49bbed043f5be260fa9f7fbff5957
# 2      2c55cae269aebf53838484b0d7dd931a
# 3      18018b6bc416dab347b1b7db79994afa
# 4      e04b990e95bf73bbe6a3fa09785d7cd0
# ...                                 ...
# 9997   1a22f23576bfdfe5ed6c887dc117aab6
# 9998   e11514dcf1f087887cd5ea0bd646d1fc
# 9999   c00301a38560da2abc89c1f86ce4b267
# 10000  c2928dbf9796ceba44863a2736afb405
# 10001  2bb94aefc3467ed83860e0e2712d5f10
#
#                                                                                                           Product Name  \
# 0                                             DB Longboards CoreFlex Crossbow 41" Bamboo Fiberglass Longboard Complete
# 1                        Electronic Snap Circuits Mini Kits Classpack, FM Radio, Motion Detector, Music Box (Set of 5)
# 2      3Doodler Create Flexy 3D Printing Filament Refill Bundle (X5 Pack, Over 1000'. of Extruded Plastics! - Innovate
# 3                                                         Guillow Airplane Design Studio with Travel Case Building Kit
# 4                                                                                     Woodstock- Collage 500 pc Puzzle
# ...                                                                                                                ...
# 9997               Remedia Publications REM536B Money Activity Book, Grade: 3 to 4, 8.5" Wide, 11" Length, 0.4" Height
# 9998                                                           Trends International NFL La Chargers HG - Mobile Wallet
# 9999               NewPath Learning 10 Piece Science Owls and Owl Pellets Curriculum Mastery Flip Chart Set, Grade 5-9
# 10000                                                                         Disney Princess Do It Yourself Braid Set
# 10001                                                                      Hasegawa Ladders Lucano Step Ladder, Orange
#
#        Brand Name  Asin  \
# 0             NaN   NaN
# 1             NaN   NaN
# 2             NaN   NaN
# 3             NaN   NaN
# 4             NaN   NaN
# ...           ...   ...
# 9997          NaN   NaN
# 9998          NaN   NaN
# 9999          NaN   NaN
# 10000         NaN   NaN
# 10001         NaN   NaN
#
#                                                                                                                                        Category  \
# 0      Sports & Outdoors | Outdoor Recreation | Skates, Skateboards & Scooters | Skateboarding | Standard Skateboards & Longboards | Longboards
# 1                                                                                     Toys & Games | Learning & Education | Science Kits & Toys
# 2                                                                                                     Toys & Games | Arts & Crafts | Craft Kits
# 3                                                               Toys & Games | Hobbies | Models & Model Kits | Model Kits | Airplane & Jet Kits
# 4                                                                                                       Toys & Games | Puzzles | Jigsaw Puzzles
# ...                                                                                                                                         ...
# 9997                                                                                 Toys & Games | Learning & Education | Counting & Math Toys
# 9998                                                                                                               Toys & Games | Arts & Crafts
# 9999                                               Office Products | Office & School Supplies | Education & Crafts | Classroom Science Supplies
# 10000                                                                                                 Toys & Games | Arts & Crafts | Craft Kits
# 10001                                                                                Home & Kitchen | Furniture | Kids' Furniture | Step Stools
#
#       Upc Ean Code  List Price Selling Price  Quantity Model Number  ...  \
# 0              NaN         NaN       $237.68       NaN          NaN  ...
# 1              NaN         NaN        $99.95       NaN        55324  ...
# 2              NaN         NaN        $34.99       NaN          NaN  ...
# 3              NaN         NaN        $28.91       NaN          142  ...
# 4              NaN         NaN        $17.49       NaN        62151  ...
# ...            ...         ...           ...       ...          ...  ...
# 9997           NaN         NaN         $9.31       NaN      REM536B  ...
# 9998           NaN         NaN         $6.99       NaN          NaN  ...
# 9999           NaN         NaN        $37.95       NaN      34-6015  ...
# 10000          NaN         NaN         $3.58       NaN     2888PRST  ...
# 10001          NaN         NaN       $152.27       NaN    ML2.0-4OR  ...
#
#                                                                               Product Url  \
# 0        https://www.amazon.com/DB-Longboards-CoreFlex-Fiberglass-Longboard/dp/B07KMVJJK7
# 1      https://www.amazon.com/Electronic-Circuits-Classpack-Motion-Detector/dp/B008AK6DAS
# 2         https://www.amazon.com/3Doodler-Plastic-Innovate-Filament-Refills/dp/B07D36747F
# 3            https://www.amazon.com/Guillow-Airplane-Design-Studio-Building/dp/B076Y2SNHM
# 4                    https://www.amazon.com/Woodstock-Collage-500-pc-Puzzle/dp/B07MX21WWX
# ...                                                                                   ...
# 9997     https://www.amazon.com/Remedia-Publications-REM536B-Money-Activity/dp/B000F8XIZ6
# 9998            https://www.amazon.com/Trends-International-NFL-Chargers-HG/dp/B07PJ181TC
# 9999     https://www.amazon.com/NewPath-Learning-Science-Pellets-Curriculum/dp/B00DOG823Y
# 10000             https://www.amazon.com/Disney-Princess-Yourself-Braid-Set/dp/B076D3P6SW
# 10001          https://www.amazon.com/Hasegawa-Ladders-Lucano-Ladder-Orange/dp/B00GG65EYE
#
#       Stock Product Details Dimensions Color Ingredients Direction To Use  \
# 0       NaN             NaN        NaN   NaN         NaN              NaN
# 1       NaN             NaN        NaN   NaN         NaN              NaN
# 2       NaN             NaN        NaN   NaN         NaN              NaN
# 3       NaN             NaN        NaN   NaN         NaN              NaN
# 4       NaN             NaN        NaN   NaN         NaN              NaN
# ...     ...             ...        ...   ...         ...              ...
# 9997    NaN             NaN        NaN   NaN         NaN              NaN
# 9998    NaN             NaN        NaN   NaN         NaN              NaN
# 9999    NaN             NaN        NaN   NaN         NaN              NaN
# 10000   NaN             NaN        NaN   NaN         NaN              NaN
# 10001   NaN             NaN        NaN   NaN         NaN              NaN
#
#        Is Amazon Seller Size Quantity Variant  Product Description
# 0                     Y                   NaN                  NaN
# 1                     Y                   NaN                  NaN
# 2                     Y                   NaN                  NaN
# 3                     Y                   NaN                  NaN
# 4                     Y                   NaN                  NaN
# ...                 ...                   ...                  ...
# 9997                  Y                   NaN                  NaN
# 9998                  Y                   NaN                  NaN
# 9999                  Y                   NaN                  NaN
# 10000                 Y                   NaN                  NaN
# 10001                 Y                   NaN                  NaN
#
# [10002 rows x 28 columns]

# %% [markdown]
# Várias colunas não possuem valores ou não são interessantes para a nossa análise, então podemos simplesmente deixá-las de fora por enquanto
#
# ##### 3º - Ajustar o DataFrame

# %%
# selecionar as colunas necessárias para a análise

columns = ['Uniq Id','Product Name','Category','Selling Price','Product Url']
df_limpo = df[columns]
df_limpo.head()
# Out:
#                             Uniq Id  \
# 0  4c69b61db1fc16e7013b43fc926e502d
# 1  66d49bbed043f5be260fa9f7fbff5957
# 2  2c55cae269aebf53838484b0d7dd931a
# 3  18018b6bc416dab347b1b7db79994afa
# 4  e04b990e95bf73bbe6a3fa09785d7cd0
#
#                                                                                                       Product Name  \
# 0                                         DB Longboards CoreFlex Crossbow 41" Bamboo Fiberglass Longboard Complete
# 1                    Electronic Snap Circuits Mini Kits Classpack, FM Radio, Motion Detector, Music Box (Set of 5)
# 2  3Doodler Create Flexy 3D Printing Filament Refill Bundle (X5 Pack, Over 1000'. of Extruded Plastics! - Innovate
# 3                                                     Guillow Airplane Design Studio with Travel Case Building Kit
# 4                                                                                 Woodstock- Collage 500 pc Puzzle
#
#                                                                                                                                    Category  \
# 0  Sports & Outdoors | Outdoor Recreation | Skates, Skateboards & Scooters | Skateboarding | Standard Skateboards & Longboards | Longboards
# 1                                                                                 Toys & Games | Learning & Education | Science Kits & Toys
# 2                                                                                                 Toys & Games | Arts & Crafts | Craft Kits
# 3                                                           Toys & Games | Hobbies | Models & Model Kits | Model Kits | Airplane & Jet Kits
# 4                                                                                                   Toys & Games | Puzzles | Jigsaw Puzzles
#
#   Selling Price  \
# 0       $237.68
# 1        $99.95
# 2        $34.99
# 3        $28.91
# 4        $17.49
#
#                                                                           Product Url
# 0    https://www.amazon.com/DB-Longboards-CoreFlex-Fiberglass-Longboard/dp/B07KMVJJK7
# 1  https://www.amazon.com/Electronic-Circuits-Classpack-Motion-Detector/dp/B008AK6DAS
# 2     https://www.amazon.com/3Doodler-Plastic-Innovate-Filament-Refills/dp/B07D36747F
# 3        https://www.amazon.com/Guillow-Airplane-Design-Studio-Building/dp/B076Y2SNHM
# 4                https://www.amazon.com/Woodstock-Collage-500-pc-Puzzle/dp/B07MX21WWX

# %% [markdown]
# ##### 4º - Encontrar itens com descrições parecidas
#
# A "recordlinkage" é a biblioteca principal nesse exercício, é por meio das funções dela que vamos fazer as comparações para chegar o nosso resultado.

# %%
import recordlinkage

# %% [markdown]
# Primeiro criamos uma cópia do nosso DataFrame inicial e vamos chamá-lo de df1.

# %%
df1 = df_limpo.copy()

# %% [markdown]
# Os métodos que vamos utilizar são o index() e o block(). O efeito esperado é que a comparação seja realizada entre os produtos da lista respeitando a categoria, nesse caso, denominada por "Category".

# %%
indexer = recordlinkage.Index()
indexer.block(left_on='Category', right_on='Category')
grupo = indexer.index(df1)

# %% [markdown]
# A próxima célula é onde a comparação é realizada. Nesse exemplo vamos identificar quais produtos possuem 90% ou mais da descrição igual a outros produtos.

# %%
comparacao = recordlinkage.Compare()
comparacao.exact('Category','Category',label='Category_Match')

# em threshold vamos deixar 90% como parâmetro de similaridade
comparacao.string('Product Name','Product Name',threshold=0.90,label='Product_Name_Match')
features = comparacao.compute(grupo, df1)

# %%
# abaixo vemos representado pelo score 2 a quantidade de itens similares e o score 1 a quantidade de comparações
features.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# 2.0       869
# 1.0    356609
# dtype: int64

# %%
# level_0 e level_1 são as posições dos index contendo as posições de itens similares
potential_matches = features[features.sum(axis=1) > 1].reset_index()
potential_matches['SCORE'] = potential_matches.loc[:, 'Category_Match':'Product_Name_Match'].sum(axis=1)
potential_matches.head(2)
# Out:
#    level_0  level_1  Category_Match  Product_Name_Match  SCORE
# 0     3564      991               1                 1.0    2.0
# 1     7213     5733               1                 1.0    2.0

# %%
# cruzando os matches

potential_matches_lv0 = potential_matches.set_index('level_0')
df1_matches = pd.merge(df1, potential_matches_lv0, 
                          left_index=True, 
                          right_index=True)

potential_matches_lv1 = potential_matches
potential_matches_lv1['J_level_1'] = potential_matches['level_1']
potential_matches_lv1 = potential_matches.set_index('level_1')

matches = pd.merge(df1_matches,
                   df1, 
                   left_on='level_1', 
                   right_index=True,
                   how='left')

# %%
# substituir espaços por "_" para facilitar a filtragem
matches.columns = matches.columns.str.replace(' ','_')

# %%
# verificar o tamanho do novo dataset
matches.shape
# Out:
# (869, 14)

# %%
matches.head(2)
# Out:
#                              Uniq_Id_x  \
# 828   58d2e7043725286b9d3cecc10ee7adc2
# 1128  a5b115b9d2ad3a3bee270d442b5155df
#
#                                                                                                                                                                                       Product_Name_x  \
# 828                                                                                                Ceaco Perfect Piece Count Puzzle - Thomas Kinkade Disney Dreams Collection - Beauty and the Beast
# 1128  MightySkins Skin Compatible with Razor A2 Kick Scooter - Rainbow Streaks | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
#
#                                                                                                         Category_x  \
# 828                                                                        Toys & Games | Puzzles | Jigsaw Puzzles
# 1128  Sports & Outdoors | Outdoor Recreation | Skates, Skateboards & Scooters | Scooters & Equipment | Accessories
#
#      Selling_Price_x  \
# 828           $16.99
# 1128             NaN
#
#                                                                        Product_Url_x  \
# 828            https://www.amazon.com/Ceaco-Perfect-Piece-Count-Puzzle/dp/B07FR9NLHW
# 1128  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MJ7LJ3R
#
#       level_1  Category_Match  Product_Name_Match  SCORE  \
# 828       205               1                 1.0    2.0
# 1128     1037               1                 1.0    2.0
#
#                              Uniq_Id_y  \
# 828   0c5298272cf8b8c881bfba43f0f9821a
# 1128  97234d1266893b950ca56a7438d1f50b
#
#                                                                                                                                                                               Product_Name_y  \
# 828                                                                                        Ceaco Perfect Piece Count Puzzle - Thomas Kinkade Disney Dreams Collection - Beauty and the Beast
# 1128  MightySkins Skin Compatible with Razor A Kick Scooter - Geo Tile | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
#
#                                                                                                         Category_y  \
# 828                                                                        Toys & Games | Puzzles | Jigsaw Puzzles
# 1128  Sports & Outdoors | Outdoor Recreation | Skates, Skateboards & Scooters | Scooters & Equipment | Accessories
#
#      Selling_Price_y  \
# 828           $19.86
# 1128             NaN
#
#                                                                        Product_Url_y
# 828            https://www.amazon.com/Ceaco-Perfect-Piece-Count-Puzzle/dp/B07FR9NJ7V
# 1128  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MF316QS

# %% [markdown]
# Agora que temos o nosso dataset indicando quais produtos são similares, vamos verificar quais produtos possuem maior quantidade de correspondentes.

# %%
agrupamento = pd.DataFrame(matches.groupby(['Uniq_Id_x','Product_Name_x'])['level_1'].count()).reset_index()
agrupamento.sort_values(by=['level_1'], ascending=False)
# Out:
#                             Uniq_Id_x  \
# 337  fc567bb32cc56b98811b39e56378cba0
# 334  fa556f12e65d41ffefe903997caad25b
# 125  638f86394e6c7e4fde07422b787899f3
# 167  7ef14575db6cbf1709219b51a6a86b7a
# 41   1db87a20cde55df8437cdb1e0fd6ad10
# ..                                ...
# 90   49d362caad6b1cf6e2b8f0608196346b
# 216  a96dc2434ff485beaf25d2e6da570ad7
# 217  aa549c9822dcb29ef81dfe2e3eaa56f4
# 218  ab792b48e348af772eb9717912c18f7e
# 174  85390919b17afd21e059b8cca56c906c
#
#                                                                                                                                                                                         Product_Name_x  \
# 337           MightySkins Skin Compatible with Razor A Kick Scooter - Color Bugs | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 334                                                                                    MightySkins Skin Compatible with Blade Chroma Battery Batteries (4 Pack) wrap Cover Sticker Skins Diamond Plate
# 125                                                                                            MightySkins Skin Compatible with Blade Chroma Battery Batteries (4 Pack) wrap Cover Sticker Skins Drops
# 167          MightySkins Skin Compatible with Razor A5 Lux Kick Scooter - Ripped | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 41                MightySkins Skin Compatible with Razor A2 Kick Scooter - Check | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# ..                                                                                                                                                                                                 ...
# 90                                                                                                MightySkins Skin Compatible with Parrot Bebop Quadcopter Drone wrap Cover Sticker Skins Black Marble
# 216                                                                                AmazonBasics Easy Care Super Soft Microfiber Kid's Bed-in-a-Bag Bedding Set - Full / Queen, Multi-Color Racing Cars
# 217  MightySkins Skin Compatible with Hover-1 H1 Hoverboard Scooter - Ink Hearts | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 218                                                                                          Little Kids Fubbles Light Up Bubble Blaster Blows tons of bubbles for Kids Includes Bubble Solution, Pink
# 174                                                                                                     Achim Home Furnishings Cordless Celestial Room Darkening Double Layered Shade 39" x 72", Black
#
#      level_1
# 337       13
# 334       12
# 125       11
# 167       11
# 41        11
# ..       ...
# 90         1
# 216        1
# 217        1
# 218        1
# 174        1
#
# [348 rows x 3 columns]

# %% [markdown]
# Vamos exibir os produtos similares do nosso top 1 do ranking

# %%
matches[['Uniq_Id_x',
         'Uniq_Id_y',
         'Product_Name_x',
         'Product_Name_y',
         'Product_Url_x',
         'Product_Url_y']].query('Uniq_Id_x == "fc567bb32cc56b98811b39e56378cba0"')
# Out:
#                              Uniq_Id_x                         Uniq_Id_y  \
# 9698  fc567bb32cc56b98811b39e56378cba0  97234d1266893b950ca56a7438d1f50b
# 9698  fc567bb32cc56b98811b39e56378cba0  a5b115b9d2ad3a3bee270d442b5155df
# 9698  fc567bb32cc56b98811b39e56378cba0  c07dc4cc0f61f940b9058af0be0bdffd
# 9698  fc567bb32cc56b98811b39e56378cba0  3aeeb156ebe76c200d185eee72ada180
# 9698  fc567bb32cc56b98811b39e56378cba0  5ca683fc36fa5c971cbd6f19b1e1d6d8
# 9698  fc567bb32cc56b98811b39e56378cba0  12d8071b784b59278722236f9ae3dd5b
# 9698  fc567bb32cc56b98811b39e56378cba0  71fc57fd48fcf9df9570ba761daeee01
# 9698  fc567bb32cc56b98811b39e56378cba0  fa9a740b822b8b314da9efd7b12f2872
# 9698  fc567bb32cc56b98811b39e56378cba0  a2e1dfe29ad3c515d5365f99d665bd32
# 9698  fc567bb32cc56b98811b39e56378cba0  3cc50f01eefa7a0debf44f3376a421c7
# 9698  fc567bb32cc56b98811b39e56378cba0  1db87a20cde55df8437cdb1e0fd6ad10
# 9698  fc567bb32cc56b98811b39e56378cba0  471e94e4f4a7dfa8167aa69b627676e9
# 9698  fc567bb32cc56b98811b39e56378cba0  7ef14575db6cbf1709219b51a6a86b7a
#
#                                                                                                                                                                                 Product_Name_x  \
# 9698  MightySkins Skin Compatible with Razor A Kick Scooter - Color Bugs | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698  MightySkins Skin Compatible with Razor A Kick Scooter - Color Bugs | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698  MightySkins Skin Compatible with Razor A Kick Scooter - Color Bugs | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698  MightySkins Skin Compatible with Razor A Kick Scooter - Color Bugs | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698  MightySkins Skin Compatible with Razor A Kick Scooter - Color Bugs | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698  MightySkins Skin Compatible with Razor A Kick Scooter - Color Bugs | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698  MightySkins Skin Compatible with Razor A Kick Scooter - Color Bugs | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698  MightySkins Skin Compatible with Razor A Kick Scooter - Color Bugs | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698  MightySkins Skin Compatible with Razor A Kick Scooter - Color Bugs | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698  MightySkins Skin Compatible with Razor A Kick Scooter - Color Bugs | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698  MightySkins Skin Compatible with Razor A Kick Scooter - Color Bugs | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698  MightySkins Skin Compatible with Razor A Kick Scooter - Color Bugs | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698  MightySkins Skin Compatible with Razor A Kick Scooter - Color Bugs | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
#
#                                                                                                                                                                                           Product_Name_y  \
# 9698              MightySkins Skin Compatible with Razor A Kick Scooter - Geo Tile | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698      MightySkins Skin Compatible with Razor A2 Kick Scooter - Rainbow Streaks | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698           MightySkins Skin Compatible with Razor A2 Kick Scooter - Black Wall | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698     MightySkins Skin Compatible with Razor A2 Kick Scooter - Green Distortion | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698        MightySkins Skin Compatible with Razor A2 Kick Scooter - Black Leather | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698  MightySkins Skin Compatible with Razor A5 Lux Kick Scooter - Splash of Color | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698         MightySkins Skin Compatible with Razor A2 Kick Scooter - Scratched Up | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698          MightySkins Skin Compatible with Razor A2 Kick Scooter - Psychedelic | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698        MightySkins Skin Compatible with Razor A Kick Scooter - Dark Butterfly | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698          MightySkins Skin Compatible with Razor A2 Kick Scooter - Blue Swirls | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698                MightySkins Skin Compatible with Razor A2 Kick Scooter - Check | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698         MightySkins Skin Compatible with Razor A2 Kick Scooter - Digital Camo | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
# 9698           MightySkins Skin Compatible with Razor A5 Lux Kick Scooter - Ripped | Protective, Durable, and Unique Vinyl Decal wrap Cover | Easy to Apply, Remove, and Change Styles | Made in The USA
#
#                                                                        Product_Url_x  \
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MF3DTT3
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MF3DTT3
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MF3DTT3
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MF3DTT3
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MF3DTT3
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MF3DTT3
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MF3DTT3
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MF3DTT3
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MF3DTT3
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MF3DTT3
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MF3DTT3
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MF3DTT3
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MF3DTT3
#
#                                                                        Product_Url_y
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MF316QS
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MJ7LJ3R
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MC16RGB
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MC15DSY
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MFM8R6N
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MC12R8N
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MC173DC
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MFM8PJF
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MF3Z8L6
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MFM8J3V
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MFM8VQC
# 9698     https://www.amazon.com/MightySkins-Compatible-A2-Kick-Scooter/dp/B07MC169B7
# 9698  https://www.amazon.com/MightySkins-Skin-Compatible-Razor-Scooter/dp/B07MFM4NJF

# %% [markdown]
# #### Conclusão
# Vimos que nesse dataset há 869 produtos que possuem descrições semelhantes em 90% do texto e fomos capazes de identificar um a um.
# Esse exercício mostrou uma maneira de encontrar itens similares em um dataset usando o Record Linkage, mas existem muitos outros métodos utilizando RL e outras bibliotecas.
